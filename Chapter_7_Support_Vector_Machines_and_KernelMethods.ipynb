# %% [markdown]
# # 🛡️ Chapter 7: Support Vector Machines and Kernel Methods
# **Referensi Buku:** *scikit-learn Cookbook, Third Edition*
#
# ---
# ## 1. Pendahuluan
# Support Vector Machines (SVM) adalah model yang sangat kuat, baik untuk klasifikasi linier maupun non-linier. Keunggulan utamanya adalah kemampuannya memaksimalkan margin pemisah antar kelas, sehingga memberikan generalisasi yang sangat baik pada data baru.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs, make_circles
from sklearn.svm import SVC

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Linear SVM dan Maximum Margin
# Kita mulai dengan data yang bisa dipisahkan secara linier. Parameter `C` mengatur seberapa keras penalti terhadap kesalahan klasifikasi. Nilai `C` yang tinggi menghasilkan margin sempit (sedikit toleransi kesalahan), sedangkan `C` kecil menghasilkan margin lebar (lebih banyak toleransi).

# %%
# Membuat data linier
X_lin, y_lin = make_blobs(n_samples=100, centers=2, random_state=6, cluster_std=1.2)

# Melatih model SVM Linear
svm_linear = SVC(kernel='linear', C=1.0)
svm_linear.fit(X_lin, y_lin)

# Visualisasi Decision Boundary dan Margins
plt.figure(figsize=(7, 5))
plt.scatter(X_lin[:, 0], X_lin[:, 1], c=y_lin, s=30, cmap='winter')

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = svm_linear.decision_function(xy).reshape(XX.shape)

# Menggambar batas keputusan dan margin
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])
# Menandai Support Vectors
ax.scatter(svm_linear.support_vectors_[:, 0], svm_linear.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k', label='Support Vectors')
plt.title('Linear SVM dan Support Vectors')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Kernel Trick (RBF) untuk Data Non-Linier
# Jika data berbentuk melingkar atau kompleks, garis lurus tidak akan berhasil. Kita menggunakan Kernel RBF (*Radial Basis Function*) yang dapat menciptakan batas keputusan yang melingkar secara elegan.

# %%
# Membuat data melingkar (non-linier)
X_circ, y_circ = make_circles(n_samples=200, noise=0.1, factor=0.4, random_state=42)

# SVM dengan RBF Kernel. Parameter 'gamma' mengatur seberapa jauh pengaruh satu titik training.
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale')
svm_rbf.fit(X_circ, y_circ)

plt.figure(figsize=(7, 5))
plt.scatter(X_circ[:, 0], X_circ[:, 1], c=y_circ, s=30, cmap='autumn')

ax = plt.gca()
xx = np.linspace(-1.5, 1.5, 50)
yy = np.linspace(-1.5, 1.5, 50)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = svm_rbf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])
plt.title('Non-Linear SVM (RBF Kernel)')
plt.show()
